# %% [markdown]
# # **~ ❄️ ANXETY sd-webui Kaggle ❄️ ~**
#
#
# <small><font color=gray>Version from: 12-02-24</small>
#
#
# <img src="https://count.getloli.com/get/@:Ayama-Colab?theme=rule34" height="90px" alt="Where did the girls go?"/>
#
# ##### Not really my work, by `DEX-1101` <-- give it stars ;3

# %% [markdown]
# # ! Download the files before use 👇 !

# %%
from IPython.utils import capture

print('Please wait for downloading...', end='')
with capture.capture_output() as cap:
    # !pip install nbconvert

    files = ['widgets_en.ipynb', 'downloading_en.ipynb', 'launch_en.ipynb']
    folder_path = '/kaggle/working/content/file_cell'
    
    # !mkdir -p {folder_path}
    
    for file in files:
        # !wget -q https://huggingface.co/NagisaNao/fast_kaggle/resolve/main/files_cells/en/{file} -O {folder_path}/{file}
        
        # !jupyter nbconvert {folder_path}/{file} --to python

del cap
print("\rDone! Now you can run the cells below :p"+ " "*30)

# %% [markdown]
# ---
# ## 1. Widgets 🔽

# %%
# Choice of models, vae, control-net and others.

with open("/kaggle/working/content/file_cell/widgets_en.py","r") as f: exec(f.read())

# %% [markdown]
# ## 2. Downloading 🔽

# %%
# Downloading lib, repo, models and other.

with open("/kaggle/working/content/file_cell/downloading_en.py","r") as f: exec(f.read())

# %% [markdown]
# ## 3. Launch 🔽

# %%
# WebUI launch.

with open("/kaggle/working/content/file_cell/launch_en.py","r") as f: exec(f.read())
