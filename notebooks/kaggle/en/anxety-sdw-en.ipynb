# %% [markdown]
# # **~ ❄️ ANXETY sd-webui Kaggle ❄️ ~**
#
#
# <small><font color=gray>Version from: 18-02-24</small>
#
#
# <img src="https://count.getloli.com/get/@:Ayama-Colab?theme=rule34" height="90px" alt="Where did the girls go?"/>

# %% [markdown]
# # ! Download files before use 👇 !

# %%
from IPython.utils import capture

lang = "en"

print('Please wait for the files to download.... 👀', end='')
with capture.capture_output() as cap:
    files = [f'widgets_{lang}.py', f'downloading_{lang}.py', f'launch_{lang}.py']
    folder_path = '/kaggle/working/content/file_cell'
    
    # !mkdir -p {folder_path}
    
    for file in files:
        # !wget -q https://huggingface.co/NagisaNao/kagglee/resolve/main/files_cells/python/{lang}/{file} -O {folder_path}/{file}

del cap
print("\rDone! Now you can run the cells below. ☄️" + " "*30)

# %% [markdown]
# ---
# ## 1. Widgets  🔽

# %%
# Model selection, vae, control-net and more.

# %run /kaggle/working/content/file_cell/widgets_{lang}.py

# %% [markdown]
# ## 2. Downloading 🔽

# %%
# Downloading libraries, repos, models and more.
# Installing libraries can take about 5 minutes~

# %run /kaggle/working/content/file_cell/downloading_{lang}.py

# %% [markdown]
# ## 3. Launch 🔽

# %%
# Launch WebUI.

# %run /kaggle/working/content/file_cell/launch_{lang}.py
