# %% [markdown]
# # **~ ❄️ ANXETY sd-webui Kaggle ❄️ ~**
#
#
# <small><font color=gray>Версия от: 12-02-24</small>
#
#
# <img src="https://count.getloli.com/get/@:Ayama-Colab?theme=rule34" height="90px" alt="Куда делись девочки?"/>
#
# ##### Не совсем моя работа, автор `DEX-1101` <-- дайте ему звёзды ;3

# %% [markdown]
# # ! Загрузите файлы перед использованием 👇 !

# %%
from IPython.utils import capture

print("Пожалуйста, подождите загрузки...", end='')
with capture.capture_output() as cap:
    # !pip install nbconvert

    files = ['widgets_ru.ipynb', 'downloading_ru.ipynb', 'launch_ru.ipynb']
    folder_path = '/kaggle/working/content/file_cell'
    
    # !mkdir -p {folder_path}
    
    for file in files:
        # !wget -q https://huggingface.co/NagisaNao/fast_kaggle/resolve/main/files_cells/ru/{file} -O {folder_path}/{file}
        
        # !jupyter nbconvert {folder_path}/{file} --to python

del cap
print("\rГотово! Теперь вы можете запустить ячейки ниже :p"+ " "*30)

# %% [markdown]
# ---
# ## 1. Виджеты 🔽

# %%
# Выбор моделей, vae, control-net и прочее.

with open("/kaggle/working/content/file_cell/widgets_ru.py","r") as f: exec(f.read())

# %% [markdown]
# ## 2. Загрузка 🔽

# %%
# Загрузка библиотек, репо, моделей и прочего.

with open("/kaggle/working/content/file_cell/downloading_ru.py","r") as f: exec(f.read())

# %% [markdown]
# ## 3. Запуск 🔽

# %%
# Запуск WebUI.

with open("/kaggle/working/content/file_cell/launch_ru.py","r") as f: exec(f.read())
